# %% [markdown]
# # TP9 Python for Data Analysis :  CNN  & RL
#
#
#
# ## un point sur pip et conda :
#
#
# https://modelpredict.com/how-not-to-break-your-python-environment-again/
#
# pip et conda sont deux gestionnaires de package python concurrents, et parfois complémentaires.
#
# pip ne gère pas les environnements,  une seule version d'une librairie peut donc etre installée.

# %%
#pour savoir ou un package est installé :
# !pip show pandas
# Out:
# Name: pandas
# Version: 1.0.5
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: None
# Author-email: None
# License: BSD
# Location: c:\users\ben\anaconda3\lib\site-packages
# Requires: pytz, python-dateutil, numpy
# Required-by: statsmodels, seaborn, catboost

# %%
# ATTENTION ! si vous lancez pip dans votre powershell, vous aurez peut être un autre résultat.
# C'est parceque pip peut être installé aussi dans un environnement conda, ce qui est le cas chez moi. Mon notebook jupyter est lancé par visualstudiocode dans un environnement conda. Le pip qui est alors dans le PATH, installe ses packages dans les dossiers conda, ce qui peut être source de conflits..

# %%
# pour lister les packages installés
# !pip list -v
# Out:
#                        0.2.0               c:\users\ben\anaconda3\lib\site-packages pip
# graphviz                           0.15                c:\users\ben\anaconda3\lib\site-packages pip
# greenlet                           0.4.16              c:\users\ben\anaconda3\lib\site-packages pip
# grpcio                             1.33.2              c:\users\ben\anaconda3\lib\site-packages pip
# h5py                               2.10.0              c:\users\ben\anaconda3\lib\site-packages pip
# HeapDict                           1.0.1               c:\users\ben\anaconda3\lib\site-packages conda
# html5lib                           1.1                 c:\users\ben\anaconda3\lib\site-packages conda
# idna                               2.10                c:\users\ben\anaconda3\lib\site-packages conda
# imageio                            2.9.0               c:\users\ben\anaconda3\lib\site-packages conda
# ...

# %% [markdown]
# Conda permet de gérer plusieurs environnements, avec des versions différentes de python, et de packages installés.

# %%
# Pour lister les environnement disponibles
# conda env list

# Pour créer un environnement.
# conda create -n TP9 

# Pour activer un environnement
# conda activate TP9

# une fois un environnement activé, toutes les conda install que vous ferez seront liées a cet environnement
# Conda vous permet aussi, dans un environnement, de choisir une version spécifique de

# %% [markdown]
# ## CPU / GPU / TPU :
#
# https://medium.com/dataseries/cpu-gpu-and-tpu-machine-learning-5033e25b8a0f
# https://www.tensorflow.org/install/gpu?hl=fr
#
#
# SI VOUS AVEZ UN GPU : essayez d'utiliser Tensorflow avec et comparer la vitesse avec le cpu
#
# KAGGLE TPU : free firepower ! faites bon usage de ces ressources mis gratuitement à votre disposition, ça n'arrive pas tous les jours..
#
# N'hésitez pas à benchmarker ( comparer le temps d'execution) les 3. Choisir la bonne plateforme fait aussi partie des compétences attendues d'un data analyst.
#
# Voici une façon de mesurer le temps d'execution de votre code.

# %%
import time
start_time = time.time()

for i in range(0,10000000):
    a=i*i

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 1.0049998760223389 seconds ---

# %% [markdown]
# ## CNN :  Type de reseau de neurones inspiré par le cortex visuel des animaux, avec un empilage de couches de perception. utile pour classifier les images, mais aussi en nlp
#
#
#
#
# COURS CNN kaggle
#
# https://www.kaggle.com/learn/computer-vision
#
# COURS CNN google
# https://www.tensorflow.org/tutorials/images/cnn
#
#
#
# MNIST FASHION CNN
#
# https://www.kaggle.com/gpreda/cnn-with-tensorflow-keras-for-fashion-mnist
#
#
# https://www.kaggle.com/pavansanagapati/a-simple-cnn-model-beginner-guide
#
#
# UTILISER LES TPU
#
# https://www.kaggle.com/jessemostipak/getting-started-tpus-cassava-leaf-disease
#
#
#
# ## RL :  un algorithme doit réaliser une tache, avec un système de reward.
# Le RL n'a pas besoin d'être supervisé, il sait trouver son chemin tout seul.
#
#
#
# Notebook Romain jouin sur le RL : https://www.dropbox.com/s/znmjp65lgscb293/ESILV_TP_7_reinforcement_learning.ipynb?dl=0
#
# Presentation  :  https://www.dropbox.com/s/7033q1eg9plg3u9/esilv_reinforcement_learning_basique.pptx?dl=0
#
# Un cours bien fait sur youtube :  https://youtu.be/cO5g5qLrLSo
#
#
# bon travail à tous.
